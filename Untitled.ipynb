# %%
import Forc

# %%
data = Forc.PMCForc('./test_data/test_forc',
                    step=50,
                    drift=False)

# %%
# %timeit data._compute_forc_sg(data.m, 3, data.step, data.step)
# Out:
# 732 µs ± 5.16 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
list(range(-1,1))
# Out:
# [-1, 0]

# %%
import util
import scipy.ndimage.filters as snf
import numpy as np
x = np.random.rand(10,10)
y = np.random.rand(100,100)

# %%
# %timeit snf.convolve(y, x, mode='constant', cval=np.nan)
# Out:
# 720 µs ± 9.93 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit -r 10 util.fast_symmetric_convolve(y, x)
# Out:
# 603 µs ± 1.62 µs per loop (mean ± std. dev. of 10 runs, 1000 loops each)

# %%
util.fast_symmetric_convolve.inspect_types()
# Out:
# fast_symmetric_convolve (array(float64, 2d, A), array(float64, 2d, A))
# --------------------------------------------------------------------------------
# # File: C:\Users\pdmurray\Desktop\Workspace\PyFORC\util.py
# # --- LINE 5 ---
# # label 0
# #   del $0.1
# #   del $0.4
# #   del $0.5
# #   del $0.2
# #   del $0.8
# #   del $0.9
# #   del $0.7
# #   del $0.10
# #   del $const0.13
# #   del $0.12
# #   del $const0.15
# #   del $0.14
# #   del $const0.17
# #   del $0.16
# #   del $const0.21
# #   del $0.20
# #   del $const0.23
# #   del $0.22
# #   del $const0.25
# #   del $0.24
# #   del $0.18
# #   del $0.26
#
# @nb.jit(nb.float64[:, :](nb.float64[:, :], nb.float64[:, :]), nopython=True)
#
# # --- LINE 6 ---
#
# def fast_symmetric_convolve(input, kernel):
#
#     # --- LINE 7 ---
#     #   input = arg(0, name=input)  :: array(float64, 2d, A)
#     #   kernel = arg(1, name=kernel)  :: array(float64, 2d, A)
# ...
