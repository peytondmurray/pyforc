# %%
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms
import pyforc.core as pfc
import numpy as np

plt.style.use('dark_background')

# %%
f = pfc.forc.Forc(
    pfc.ingester.PMCIngester,
    pfc.config.Config(
        file_name='/home/pdmurray/Desktop/workspace/pyforc/tests/fixtures/hchb_forc',
        interpolation='linear',
        pipeline=[
            pfc.ops.correct_drift,
            pfc.ops.interpolate,
        ]
    )
)

# %%
chhr = pfc.coordinates.CoordinatesHHr()
chchb = pfc.coordinates.CoordinatesHcHb()

# %%
f.data.get_extent(chchb)
# Out:
# (-4140.77, 6808.535, -4140.77, 1140.678)

# %%
ax = pfc.plot.imshow(f, coords='hhr', mask=True)

# %%
ax = pfc.plot.imshow(f, coords='hchb', mask=True)

# %%
t = transforms.Affine2D()
t.get_matrix()
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
t.rotate(np.pi/4)
t.get_matrix()
# Out:
# array([[ 0.70710678, -0.70710678,  0.        ],
#        [ 0.70710678,  0.70710678,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])
