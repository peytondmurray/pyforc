# %%
# %matplotlib inline
# %load_ext snakeviz
import Forc
import plotting
import matplotlib.pyplot as plt
import matplotlib.transforms as mt
import numpy as np
import util
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz

# %%
data = Forc.PMCForc('./test_data/test_forc', step=None).slope_correction().normalize().compute_forc_distribution()

# %%
data.get_extent('hhr')
# Out:
# [-4368.107587194621, 6823.89670546362, -4158.257506707279, 1157.9445323053847]

# %%
hc, hb = util.hhr_to_hchb(data.h, data.hr)

# %%
plt.imshow(hc, origin='lower', cmap='viridis')

# %%
np.nanmax(hc[np.nonzero(1 - np.isnan(hc + data.m))])
# Out:
# 4162.026596332284

# %%
transform = mt.Affine2D(matrix=np.array([[0.5, -0.5, 0], [0.5, 0.5, 0], [0, 0, 1]]))

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
im = ax.imshow(data.get_masked(data.m, 'h<hr', 'hhr'), origin='lower', extent=data.get_extent('hhr'), cmap='RdBu_r')
print(data.get_extent('hhr'))
# im.set_transform(transform + ax.transData)
# Out:
# [-4368.107587194621, 6823.89670546362, -4158.257506707279, 1157.9445323053847]

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
im = ax.imshow(data.get_masked(data.m, 'h<hr', 'hhr'), origin='lower', extent=data.get_extent('hhr'), cmap='RdBu_r')
print(data.get_extent('hchb'))
im.set_transform(ax.transData)
# Out:
# [-2757.9040876214863, 4166.795276485095, -4258.060574822433, 2641.907720126752]

# %%
print(ax.contour.__doc__)
# Out:
#         Plot contours.
#
#         :func:`~matplotlib.pyplot.contour` and
#         :func:`~matplotlib.pyplot.contourf` draw contour lines and
#         filled contours, respectively.  Except as noted, function
#         signatures and return values are the same for both versions.
#
#         :func:`~matplotlib.pyplot.contourf` differs from the MATLAB
#         version in that it does not draw the polygon edges.
#         To draw edges, add line contours with
#         calls to :func:`~matplotlib.pyplot.contour`.
#
#
#         Call signatures::
#
#           contour(Z)
#
#         make a contour plot of an array *Z*. The level values are chosen
#         automatically.
#
#         ::
#
#           contour(X,Y,Z)
#
#         *X*, *Y* specify the (x, y) coordinates of the surface
#
#         ::
#
#           contour(Z,N)
#           contour(X,Y,Z,N)
#
#         contour up to *N+1* automatically chosen contour levels
#         (*N* intervals).
#
#         ::
#
#           contour(Z,V)
# ...
